# %%
# %load_ext lab_black

# %%
from dataframe_example import ApertureInputUi

# %% [markdown]
# Note, this UI effectively has an extra unnecessary layer in it as I needed a way to split the UI up into different sections with their own headers

# %%
ui = ApertureInputUi()
display(ui)
# Out:
# ApertureInputUi(children=(AutoObject(children=(VBox(children=(AutoBox(children=(HBox(children=(ToggleButton(va…

# %% [markdown]
# So, the below function accesses the values dictionary. This is a dictionary with multiple levels. The first one is getting the list that is associated with the key "apertures" (see note above). This is a list of all of the dictionaries that are associated with each aperture (I have nested dictionaries within each other, this may not be good practice). `[0]` indexes the list to get the dictionary corresponding to the first aperture. Then, `.get("aperture_name")` accesses the name of the aperture that is in the dictionary.

# %%
ui.value.get("apertures")[0].get("aperture_name")
# Out:
# 'window1'
